# %%
# Import dependencies

import requests
import pandas as pd
import json
import numpy as np
from config import api_key
from pprint import pprint
from urllib.parse import quote
import matplotlib.pyplot as plt

# %%
# List for cities to search

search_cities = ['Bell', 'Manhattan Beach', 'Claremont', 
                 'West Hollywood', 'Beverly Hills', 'San Dimas', 
                 'Lawndale', 'La Verne', 'Walnut', 'Maywood', 
                 'South Pasadena']

for city in search_cities:

    def restaurant_response(set_num): 
    # This function launches the request for all food truck endpoints in Los Angeles, CA.

        url = 'https://api.yelp.com/v3/businesses/search'
        headers = {
            'Authorization': 'Bearer {}'.format(api_key),
        }
        url_params = { #parameters passed to the API
        "term": 'food trucks',
        "location": city,
        "state": "California",
        'offset': offset_num, # We are going to iterate the offset
         "limit":50 # Maximum return of results per request (ref: API documentation).
         }

        response = requests.get(url, headers=headers, params=url_params)
        response = response.json() # Returns a JSON.
        return response

    for offset_num in np.arange(50,200,50) : 
        try:
            output_json = restaurant_response(offset_num) # Executing the function defined above.
            print(offset_num) # Making sure each offset iteration is running
            pprint(output_json,indent=4) # If you wanna check the JSON for each iteration
            if offset_num == 50:
                df_first = pd.DataFrame.from_dict(output_json['businesses'])

            else:
                df2 = pd.DataFrame.from_dict(output_json['businesses'])

                df_first = pd.concat([df_first, df2])

    # The conditional statement above is so that I can append my results into a single dataframe, to 
    # save into a single csv document.
        except AttributeError:
            print("error at ", offset_num) # Helpful for debugging purposes

    #         df_first.to_json("./output/output_data.json")

    # Saves the food truck data to csv file                        

        df_first.to_csv(f"./{city}output_data.csv", index = False)
# Out:
# 50
# {   'businesses': [   {   'alias': 'african-chop-los-angeles',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'african',
#                                                 'title': 'African'}],
#                           'coordinates': {   'latitude': 33.97853,
#                                              'longitude': -118.2497},
#                           'display_phone': '(408) 429-5458',
#                           'distance': 5501.293767244812,
#                           'id': 'E02jtyN7b9LJW8bJwX97kA',
#                           'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JjrtjbLEAClF4x_OCkoGlw/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': None,
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   'Los Angeles, '
#                                                                  'CA 90001'],
#                                           'state': 'CA',
#                                           'zip_code': '90001'},
#                           'name': 'African Chop',
#                           'phone': '+14084295458',
#                           'rating': 4.5,
#                           'review_count': 26,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/african-chop-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'hunger-sticks-los-angeles',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'asianfusion',
#                                                 'title': 'Asian Fusion'}],
#                           'coordinates': {   'latitude': 34.04689,
#                                              'longitude': -118.21284},
#                           'display_phone': '(213) 444-4647',
#                           'distance': 8668.50082101108,
#                           'id': 'RFGINN-NvTscePX2RmT1aw',
#                           'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0w0VjIWgm8NmbeiCh_Ctvg/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '',
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   'Los Angeles, '
#                                                                  'CA 90033'],
#                                           'state': 'CA',
#                                           'zip_code': '90033'},
#                           'name': 'Hunger Sticks',
#                           'phone': '+12134444647',
#                           'rating': 4.0,
#                           'review_count': 11,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/hunger-sticks-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'el-pariente-huntington-park-2',
#                           'categories': [   {   'alias': 'mexican',
#                                                 'title': 'Mexican'},
#                                             {   'alias': 'seafood',
#                                                 'title': 'Seafood'},
#                                             {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'}],
#                           'coordinates': {   'latitude': 33.9722099,
#                                              'longitude': -118.22493},
#                           'display_phone': '(323) 537-8030',
#                           'distance': 3465.220866564211,
#                           'id': '2qmIiaa93nIgrGkY8As8Zw',
#                           'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xxY1ThihbFeJTz796BPQ6g/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '7400 Pacific Blvd',
#                                           'address2': '',
#                                           'address3': '',
#                                           'city': 'Huntington Park',
#                                           'country': 'US',
#                                           'display_address': [   '7400 Pacific '
#                                                                  'Blvd',
#                                                                  'Huntington '
#                                                                  'Park, CA '
#                                                                  '90255'],
#                                           'state': 'CA',
#                                           'zip_code': '90255'},
#                           'name': 'El Pariente',
#                           'phone': '+13235378030',
#                           'price': '$',
#                           'rating': 4.0,
#                           'review_count': 17,
#                           'transactions': ['delivery'],
#                           'url': 'https://www.yelp.com/biz/el-pariente-huntington-park-2?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'wings-n-waffles-los-angeles',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'catering',
#                                                 'title': 'Caterers'}],
#                           'coordinates': {   'latitude': 34.05814,
#                                              'longitude': -118.24666},
#                           'display_phone': '(818) 738-0469',
#                           'distance': 11313.608661821883,
#                           'id': 'bx98Nr15LUBntgc9kqP15w',
#                           'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mGOA6D-PIKdCqhVLa1NCRA/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '',
#                                           'address2': '',
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   'Los Angeles, '
#                                                                  'CA 90012'],
#                                           'state': 'CA',
#                                           'zip_code': '90012'},
#                           'name': 'Wings N Waffles',
#                           'phone': '+18187380469',
#                           'price': '$',
#                           'rating': 4.5,
#                           'review_count': 97,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/wings-n-waffles-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'roaming-hunger-west-hollywood-2',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'catering',
#                                                 'title': 'Caterers'}],
#                           'coordinates': {   'latitude': 34.097384,
#                                              'longitude': -118.3683601},
#                           'display_phone': '(800) 568-9370',
#                           'distance': 21519.197906818696,
#                           'id': 'vzhLgBuAwcFuVwltFKR8nA',
#                           'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pr2up-NaMRbOQ44BTkejYA/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '8228 W Sunset Blvd',
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'West Hollywood',
#                                           'country': 'US',
#                                           'display_address': [   '8228 W '
#                                                                  'Sunset Blvd',
#                                                                  'West '
#                                                                  'Hollywood, '
#                                                                  'CA 90046'],
#                                           'state': 'CA',
#                                           'zip_code': '90046'},
#                           'name': 'Roaming Hunger',
#                           'phone': '+18005689370',
#                           'price': '$$',
#                           'rating': 4.0,
#                           'review_count': 124,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/roaming-hunger-west-hollywood-2?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'mariscos-el-patron-los-angeles',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'}],
#                           'coordinates': {   'latitude': 33.920023,
#                                              'longitude': -118.265191},
#                           'display_phone': '(323) 517-3668',
#                           'distance': 9418.133498313362,
#                           'id': 'ygmXcK8T4O85k6CQL_IyFA',
#                           'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zTzZIC9vVo68hsyN5X7hSQ/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '12400-12416 S Avalon '
#                                                       'Blvd',
#                                           'address2': '',
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   '12400-12416 '
#                                                                  'S Avalon '
#                                                                  'Blvd',
#                                                                  'Los Angeles, '
#                                                                  'CA 90061'],
#                                           'state': 'CA',
#                                           'zip_code': '90061'},
#                           'name': 'Mariscos El Patron',
#                           'phone': '+13235173668',
#                           'price': '$',
#                           'rating': 5.0,
#                           'review_count': 3,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/mariscos-el-patron-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'la-casita-mexicana-bell',
#                           'categories': [   {   'alias': 'mexican',
#                                                 'title': 'Mexican'},
#                                             {   'alias': 'catering',
#                                                 'title': 'Caterers'}],
#                           'coordinates': {   'latitude': 33.9786,
#                                              'longitude': -118.19515},
#                           'display_phone': '(323) 773-1898',
#                           'distance': 817.3390327615481,
#                           'id': '_Gzb8oDw4QNbAVIqW9Kanw',
#                           'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WYu-BmPMO2r677qxzcvqBQ/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '4030 E Gage Ave',
#                                           'address2': '',
#                                           'address3': '',
#                                           'city': 'Bell',
#                                           'country': 'US',
#                                           'display_address': [   '4030 E Gage '
#                                                                  'Ave',
#                                                                  'Bell, CA '
#                                                                  '90201'],
#                                           'state': 'CA',
#                                           'zip_code': '90201'},
#                           'name': 'La Casita Mexicana',
#                           'phone': '+13237731898',
#                           'price': '$$',
#                           'rating': 4.0,
#                           'review_count': 1079,
#                           'transactions': ['delivery', 'pickup'],
#                           'url': 'https://www.yelp.com/biz/la-casita-mexicana-bell?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'mariscos-tocho-los-angeles',
#                           'categories': [   {   'alias': 'seafood',
#                                                 'title': 'Seafood'},
#                                             {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'tacos',
#                                                 'title': 'Tacos'}],
#                           'coordinates': {   'latitude': 33.9346389704683,
#                                              'longitude': -118.226422399082},
#                           'display_phone': '(562) 415-7519',
#                           'distance': 5745.053696179527,
#                           'id': 'P8jOe65n-VSNt0KjS7PCQQ',
#                           'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VoOHcG-fWubR8V0qoOM9TQ/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '11267 SAlameda St',
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   '11267 '
#                                                                  'SAlameda St',
#                                                                  'Los Angeles, '
#                                                                  'CA 90059'],
#                                           'state': 'CA',
#                                           'zip_code': '90059'},
#                           'name': 'Mariscos Tocho',
#                           'phone': '+15624157519',
#                           'price': '$',
#                           'rating': 4.5,
#                           'review_count': 71,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/mariscos-tocho-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'birrieria-gonzalez-vernon-2',
#                           'categories': [   {   'alias': 'mexican',
#                                                 'title': 'Mexican'}],
#                           'coordinates': {   'latitude': 33.99802,
#                                              'longitude': -118.22437},
#                           'display_phone': '(323) 642-4203',
#                           'distance': 4340.5758317061445,
#                           'id': 'nz9KqsFgohueQEY_fFdKYg',
#                           'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uWGzQLh5VkjKl2JKmg2vDw/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '5000 Pacific Blvd',
#                                           'address2': '',
#                                           'address3': None,
#                                           'city': 'Vernon',
#                                           'country': 'US',
#                                           'display_address': [   '5000 Pacific '
#                                                                  'Blvd',
#                                                                  'Vernon, CA '
#                                                                  '90058'],
#                                           'state': 'CA',
#                                           'zip_code': '90058'},
#                           'name': 'Birrieria Gonzalez',
#                           'phone': '+13236424203',
#                           'price': '$$',
#                           'rating': 3.5,
#                           'review_count': 49,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/birrieria-gonzalez-vernon-2?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'fries-first-los-angeles',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'gourmet',
#                                                 'title': 'Specialty Food'}],
#                           'coordinates': {   'latitude': 34.05349,
#                                              'longitude': -118.24532},
#                           'display_phone': '(510) 213-0780',
#                           'distance': 10032.509364624957,
#                           'id': '2uISFQHKKLPmF27myEX2rA',
#                           'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1kshTJRqRY4BKK2nTaC45w/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': None,
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   'Los Angeles, '
#                                                                  'CA'],
#                                           'state': 'CA',
#                                           'zip_code': ''},
#                           'name': 'Fries First',
#                           'phone': '+15102130780',
#                           'price': '$$',
#                           'rating': 5.0,
#                           'review_count': 25,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/fries-first-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'julies-taco-bar-maywood',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'mexican',
#                                                 'title': 'Mexican'}],
#                           'coordinates': {   'latitude': 33.9835152447,
#                                              'longitude': -118.181267381},
#                           'display_phone': '(323) 835-7393',
#                           'distance': 1110.1066799283742,
#                           'id': 'DD6KklyUoxlA5Hc8FLB6hw',
#                           'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/j8GOMUQyPJqS2EvLwDT2iA/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': None,
#                                           'address2': None,
#                                           'address3': None,
#                                           'city': 'Maywood',
#                                           'country': 'US',
#                                           'display_address': [   'Maywood, CA '
#                                                                  '90270'],
#                                           'state': 'CA',
#                                           'zip_code': '90270'},
#                           'name': "Julie's Taco Bar",
#                           'phone': '+13238357393',
#                           'rating': 4.0,
#                           'review_count': 1,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/julies-taco-bar-maywood?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'the-gooey-gourmet-pasadena',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'catering',
#                                                 'title': 'Caterers'}],
#                           'coordinates': {   'latitude': 34.14764,
#                                              'longitude': -118.14353},
#                           'display_phone': '(626) 508-5272',
#                           'distance': 19623.334368167874,
#                           'id': 'eta8oV3RpXXXyVZKm9wCSA',
#                           'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/o6NaQAI-UiPpWVBVSu0Vzw/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '100 Garfield Ave',
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Pasadena',
#                                           'country': 'US',
#                                           'display_address': [   '100 Garfield '
#                                                                  'Ave',
#                                                                  'Pasadena, CA '
#                                                                  '91101'],
#                                           'state': 'CA',
#                                           'zip_code': '91101'},
#                           'name': 'The Gooey Gourmet',
#                           'phone': '+16265085272',
#                           'rating': 5.0,
#                           'review_count': 1,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/the-gooey-gourmet-pasadena?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'achara-food-truck-los-angeles',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'filipino',
#                                                 'title': 'Filipino'},
#                                             {   'alias': 'bbq',
#                                                 'title': 'Barbeque'}],
#                           'coordinates': {   'latitude': 34.05349,
#                                              'longitude': -118.24532},
#                           'display_phone': '(323) 609-8483',
#                           'distance': 10032.509364624957,
#                           'id': 'T5Qv6Xsb0LT7s48dnO3iKA',
#                           'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zZQLYOHnFAdIUZHLe4oczw/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '',
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   'Los Angeles, '
#                                                                  'CA'],
#                                           'state': 'CA',
#                                           'zip_code': ''},
#                           'name': 'Achara Food Truck',
#                           'phone': '+13236098483',
#                           'price': '$$',
#                           'rating': 4.0,
#                           'review_count': 48,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/achara-food-truck-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'churro-boss-monterey-park-8',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'}],
#                           'coordinates': {   'latitude': 34.064898,
#                                              'longitude': -118.133709},
#                           'display_phone': '(213) 618-2585',
#                           'distance': 11160.75626430878,
#                           'id': 'cYcNYyqchuOy_y-jiBKF0g',
#                           'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/S1ba_qieCHYww-frICwF7g/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '300 N Atlantic Blvd',
#                                           'address2': None,
#                                           'address3': None,
#                                           'city': 'Monterey Park ',
#                                           'country': 'US',
#                                           'display_address': [   '300 N '
#                                                                  'Atlantic '
#                                                                  'Blvd',
#                                                                  'Monterey '
#                                                                  'Park , CA '
#                                                                  '91754'],
#                                           'state': 'CA',
#                                           'zip_code': '91754'},
#                           'name': 'Churro Boss',
#                           'phone': '+12136182585',
#                           'price': '$',
#                           'rating': 4.5,
#                           'review_count': 213,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/churro-boss-monterey-park-8?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'tejuinos-colima-los-angeles',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'juicebars',
#                                                 'title': 'Juice Bars & '
#                                                          'Smoothies'}],
#                           'coordinates': {   'latitude': 33.945001461309,
#                                              'longitude': -118.22846939137},
#                           'display_phone': '(310) 729-6726',
#                           'distance': 5038.80376366471,
#                           'id': 'ZbhMgE-2ngghdDFKNPdIGg',
#                           'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Tw_jdBTtYNmNBvEAuE9XqA/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '10085 Alameda St',
#                                           'address2': '',
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   '10085 '
#                                                                  'Alameda St',
#                                                                  'Los Angeles, '
#                                                                  'CA 90002'],
#                                           'state': 'CA',
#                                           'zip_code': '90002'},
#                           'name': 'Tejuinos Colima',
#                           'phone': '+13107296726',
#                           'price': '$',
#                           'rating': 5.0,
#                           'review_count': 5,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/tejuinos-colima-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'mac-n-cheese-rebel-los-angeles-2',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'vegan',
#                                                 'title': 'Vegan'}],
#                           'coordinates': {   'latitude': 34.1217589601142,
#                                              'longitude': -118.206167250797},
#                           'display_phone': '(323) 627-1499',
#                           'distance': 16413.108569468375,
#                           'id': 'ybD4vMxuQXacD95Km90I9Q',
#                           'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cdr9Qgy0RaZaOHehQA1KLA/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '5031 York Blvd',
#                                           'address2': None,
#                                           'address3': None,
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   '5031 York '
#                                                                  'Blvd',
#                                                                  'Los Angeles, '
#                                                                  'CA 90042'],
#                                           'state': 'CA',
#                                           'zip_code': '90042'},
#                           'name': "Mac n' Cheese Rebel",
#                           'phone': '+13236271499',
#                           'rating': 4.5,
#                           'review_count': 50,
#                           'transactions': ['delivery'],
#                           'url': 'https://www.yelp.com/biz/mac-n-cheese-rebel-los-angeles-2?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'chicken-and-waffle-factory-los-angeles',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'waffles',
#                                                 'title': 'Waffles'},
#                                             {   'alias': 'sandwiches',
#                                                 'title': 'Sandwiches'}],
#                           'coordinates': {   'latitude': 34.00455,
#                                              'longitude': -118.26009},
#                           'display_phone': '(310) 844-3237',
#                           'distance': 7501.933316921523,
#                           'id': 'u6iiP3Ck2TdhHHtN7keJCA',
#                           'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZDFREqmd2CrxWAD7TA9d4w/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '',
#                                           'address2': '',
#                                           'address3': None,
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   'Los Angeles, '
#                                                                  'CA 90011'],
#                                           'state': 'CA',
#                                           'zip_code': '90011'},
#                           'name': 'Chicken and Waffle Factory',
#                           'phone': '+13108443237',
#                           'rating': 4.0,
#                           'review_count': 17,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/chicken-and-waffle-factory-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'culichi-town-bell-bell',
#                           'categories': [   {   'alias': 'sushi',
#                                                 'title': 'Sushi Bars'},
#                                             {   'alias': 'mexican',
#                                                 'title': 'Mexican'},
#                                             {   'alias': 'seafood',
#                                                 'title': 'Seafood'}],
#                           'coordinates': {   'latitude': 33.97527,
#                                              'longitude': -118.1869},
#                           'display_phone': '(323) 773-1278',
#                           'distance': 54.07306317718198,
#                           'id': 'vrUgDkt71DugSpsYWmDDFw',
#                           'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2mIc96YdOSL8dR__gEcLXQ/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '6638 Atlantic Ave',
#                                           'address2': '',
#                                           'address3': '',
#                                           'city': 'Bell',
#                                           'country': 'US',
#                                           'display_address': [   '6638 '
#                                                                  'Atlantic Ave',
#                                                                  'Bell, CA '
#                                                                  '90201'],
#                                           'state': 'CA',
#                                           'zip_code': '90201'},
#                           'name': 'Culichi Town - Bell',
#                           'phone': '+13237731278',
#                           'price': '$$',
#                           'rating': 3.0,
#                           'review_count': 833,
#                           'transactions': ['delivery'],
#                           'url': 'https://www.yelp.com/biz/culichi-town-bell-bell?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'mariscos-y-tacos-el-compa-east-los-angeles',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'seafood',
#                                                 'title': 'Seafood'},
#                                             {   'alias': 'mexican',
#                                                 'title': 'Mexican'}],
#                           'coordinates': {   'latitude': 34.0124281305428,
#                                              'longitude': -118.136739344117},
#                           'display_phone': '(323) 216-7956',
#                           'distance': 6264.066475941899,
#                           'id': 'egrJYW0UAdZ7Dd1HxXyt-g',
#                           'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TrjU-WcglfPZqJAToo32nA/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '6250 E Olympic Blvd',
#                                           'address2': '',
#                                           'address3': None,
#                                           'city': 'East Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   '6250 E '
#                                                                  'Olympic Blvd',
#                                                                  'East Los '
#                                                                  'Angeles, CA '
#                                                                  '90022'],
#                                           'state': 'CA',
#                                           'zip_code': '90022'},
#                           'name': 'Mariscos Y Tacos El Compa',
#                           'phone': '+13232167956',
#                           'price': '$',
#                           'rating': 4.0,
#                           'review_count': 7,
#                           'transactions': ['delivery'],
#                           'url': 'https://www.yelp.com/biz/mariscos-y-tacos-el-compa-east-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'los-3-potrillos-huntington-park',
#                           'categories': [   {   'alias': 'tacos',
#                                                 'title': 'Tacos'},
#                                             {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'}],
#                           'coordinates': {   'latitude': 33.98772683,
#                                              'longitude': -118.20267183},
#                           'display_phone': '',
#                           'distance': 2019.6133860018556,
#                           'id': 'kWstm_6pB7kSjGCiNSJkLw',
#                           'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U_kWZGIyIWID63joZ1K47g/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '5959 Maywood Ave',
#                                           'address2': '',
#                                           'address3': None,
#                                           'city': 'Huntington Park',
#                                           'country': 'US',
#                                           'display_address': [   '5959 Maywood '
#                                                                  'Ave',
#                                                                  'Huntington '
#                                                                  'Park, CA '
#                                                                  '90255'],
#                                           'state': 'CA',
#                                           'zip_code': '90255'},
#                           'name': 'Los 3 Potrillos',
#                           'phone': '',
#                           'rating': 3.5,
#                           'review_count': 2,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/los-3-potrillos-huntington-park?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'munching-it-whittier',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'}],
#                           'coordinates': {   'latitude': 33.9763526916504,
#                                              'longitude': -118.072242736816},
#                           'display_phone': '(323) 742-1542',
#                           'distance': 10718.103945362433,
#                           'id': 'gQ03rtHq3NhsewDhN1OGSA',
#                           'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TZcQPcVG2z0fPZpsaPUVkQ/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': None,
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Whittier',
#                                           'country': 'US',
#                                           'display_address': [   'Whittier, CA '
#                                                                  '90606'],
#                                           'state': 'CA',
#                                           'zip_code': '90606'},
#                           'name': 'Munching It',
#                           'phone': '+13237421542',
#                           'rating': 5.0,
#                           'review_count': 4,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/munching-it-whittier?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'the-steamin-burger-los-angeles',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'}],
#                           'coordinates': {   'latitude': 34.03198,
#                                              'longitude': -118.2442},
#                           'display_phone': '(323) 374-5747',
#                           'distance': 7774.276140703874,
#                           'id': 'IcVAGTh5Luqo4ONMmLlYpQ',
#                           'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j1jFkoJP63KYoQeP0oxNIg/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': None,
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   'Los Angeles, '
#                                                                  'CA 90021'],
#                                           'state': 'CA',
#                                           'zip_code': '90021'},
#                           'name': "The Steamin' Burger",
#                           'phone': '+13233745747',
#                           'rating': 5.0,
#                           'review_count': 4,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/the-steamin-burger-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'badchkn-glendale',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'tradamerican',
#                                                 'title': 'American '
#                                                          '(Traditional)'},
#                                             {   'alias': 'chicken_wings',
#                                                 'title': 'Chicken Wings'}],
#                           'coordinates': {   'latitude': 34.136914,
#                                              'longitude': -118.24043},
#                           'display_phone': '(818) 221-8874',
#                           'distance': 18656.629750854754,
#                           'id': 'PwMPj1HA4KAKzbu8feHIFA',
#                           'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E1H4gan8OMhvnTVtNdkSYA/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '801 S Chevy Chase Dr',
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Glendale',
#                                           'country': 'US',
#                                           'display_address': [   '801 S Chevy '
#                                                                  'Chase Dr',
#                                                                  'Glendale, CA '
#                                                                  '91205'],
#                                           'state': 'CA',
#                                           'zip_code': '91205'},
#                           'name': 'Badchkn',
#                           'phone': '+18182218874',
#                           'rating': 4.5,
#                           'review_count': 21,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/badchkn-glendale?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'pinch-of-flavor-los-angeles-2',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'sushi',
#                                                 'title': 'Sushi Bars'},
#                                             {'alias': 'poke', 'title': 'Poke'}],
#                           'coordinates': {   'latitude': 34.06239,
#                                              'longitude': -118.30697},
#                           'display_phone': '(213) 880-5513',
#                           'distance': 14689.25848626483,
#                           'id': 'N-_ySUnohAQGMItCE318rA',
#                           'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KVT8q4ix3c65kBOuOq-M1g/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '3701 Wilshire Blvd',
#                                           'address2': '',
#                                           'address3': None,
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
# ...
#                                           'address3': '',
#                                           'city': 'Bellflower',
#                                           'country': 'US',
#                                           'display_address': [   'Bellflower, '
#                                                                  'CA 90706'],
#                                           'state': 'CA',
#                                           'zip_code': '90706'},
#                           'name': 'GoodFellas Taco Catering',
#                           'phone': '+19093335527',
#                           'price': '$$',
#                           'rating': 4.5,
#                           'review_count': 34,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/goodfellas-taco-catering-bellflower?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'about-time-catering-los-angeles',
#                           'categories': [   {   'alias': 'catering',
#                                                 'title': 'Caterers'}],
#                           'coordinates': {   'latitude': 33.9910774230957,
#                                              'longitude': -118.26570892334},
#                           'display_phone': '(323) 231-5343',
#                           'distance': 17107.3390634617,
#                           'id': 'PQWJ3VbSlwloBR9SHdap7w',
#                           'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uWIJILzhKurLmgBh4GptYA/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '5625 Avalon Blvd',
#                                           'address2': '',
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   '5625 Avalon '
#                                                                  'Blvd',
#                                                                  'Los Angeles, '
#                                                                  'CA 90011'],
#                                           'state': 'CA',
#                                           'zip_code': '90011'},
#                           'name': 'About Time Catering',
#                           'phone': '+13232315343',
#                           'rating': 3.0,
#                           'review_count': 2,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/about-time-catering-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'mad-dumplings-santa-ana',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'asianfusion',
#                                                 'title': 'Asian Fusion'},
#                                             {   'alias': 'chinese',
#                                                 'title': 'Chinese'}],
#                           'coordinates': {   'latitude': 33.712281,
#                                              'longitude': -117.872117},
#                           'display_phone': '(818) 583-7137',
#                           'distance': 51655.4974878684,
#                           'id': '-Br-JIbWn_9tC5SIdvgcOQ',
#                           'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S7B_WwL-VK9_BzfzKzXEJw/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '2530 South Birch St',
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Santa Ana',
#                                           'country': 'US',
#                                           'display_address': [   '2530 South '
#                                                                  'Birch St',
#                                                                  'Santa Ana, '
#                                                                  'CA 92707'],
#                                           'state': 'CA',
#                                           'zip_code': '92707'},
#                           'name': 'Mad Dumplings',
#                           'phone': '+18185837137',
#                           'price': '$$',
#                           'rating': 4.0,
#                           'review_count': 234,
#                           'transactions': ['pickup', 'delivery'],
#                           'url': 'https://www.yelp.com/biz/mad-dumplings-santa-ana?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'bling-bling-dumpling-los-angeles',
#                           'categories': [   {   'alias': 'catering',
#                                                 'title': 'Caterers'}],
#                           'coordinates': {   'latitude': 34.1147313,
#                                              'longitude': -118.3637264},
#                           'display_phone': '(323) 308-0636',
#                           'distance': 19338.406500074794,
#                           'id': 'dIcQ4lIIwh3jKq4-DMNATg',
#                           'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/w1jIH2iUhTDEjEDNdKyTJA/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': None,
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   'Los Angeles, '
#                                                                  'CA 90046'],
#                                           'state': 'CA',
#                                           'zip_code': '90046'},
#                           'name': 'Bling Bling Dumpling',
#                           'phone': '+13233080636',
#                           'rating': 4.0,
#                           'review_count': 39,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/bling-bling-dumpling-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'shawarma-and-falafel-palace-food-truck-los-angeles',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'mideastern',
#                                                 'title': 'Middle Eastern'}],
#                           'coordinates': {   'latitude': 34.21332,
#                                              'longitude': -118.35861},
#                           'display_phone': '(818) 282-4301',
#                           'distance': 21871.576980695154,
#                           'id': 'p80H4LNPVe3rUB7YBjH4bg',
#                           'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PqIyfkgdazQ46xaSs_VFzw/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '7782 San Fernando Rd',
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   '7782 San '
#                                                                  'Fernando Rd',
#                                                                  'Los Angeles, '
#                                                                  'CA 91352'],
#                                           'state': 'CA',
#                                           'zip_code': '91352'},
#                           'name': 'Shawarma and Falafel Palace Food Truck',
#                           'phone': '+18182824301',
#                           'price': '$',
#                           'rating': 1.0,
#                           'review_count': 1,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/shawarma-and-falafel-palace-food-truck-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'hustle-n-dough-los-angeles',
#                           'categories': [   {   'alias': 'donuts',
#                                                 'title': 'Donuts'},
#                                             {   'alias': 'coffee',
#                                                 'title': 'Coffee & Tea'},
#                                             {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'}],
#                           'coordinates': {   'latitude': 34.004258,
#                                              'longitude': -118.427688},
#                           'display_phone': '(323) 553-0584',
#                           'distance': 28027.69878027197,
#                           'id': 'bUkylDwlzjysKD3ezKHmoA',
#                           'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pLQ7dfFkHJtz-SpuKUYARg/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '3905 Inglewood Blvd',
#                                           'address2': 'Ste 202',
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   '3905 '
#                                                                  'Inglewood '
#                                                                  'Blvd',
#                                                                  'Ste 202',
#                                                                  'Los Angeles, '
#                                                                  'CA 90066'],
#                                           'state': 'CA',
#                                           'zip_code': '90066'},
#                           'name': 'Hustle N Dough',
#                           'phone': '+13235530584',
#                           'rating': 4.5,
#                           'review_count': 9,
#                           'transactions': ['pickup', 'delivery'],
#                           'url': 'https://www.yelp.com/biz/hustle-n-dough-los-angeles?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'ice-cream-roll-los-angeles-6',
#                           'categories': [   {   'alias': 'desserts',
#                                                 'title': 'Desserts'},
#                                             {   'alias': 'icecream',
#                                                 'title': 'Ice Cream & Frozen '
#                                                          'Yogurt'},
#                                             {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'}],
#                           'coordinates': {   'latitude': 34.1016299248973,
#                                              'longitude': -118.333691404536},
#                           'display_phone': '(323) 578-8811',
#                           'distance': 16629.468826606288,
#                           'id': 'lkYF49T_tDdVf7VbjXHxBw',
#                           'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M1UD6qdjnNamoqWCQQHezg/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': '6611 Hollywood Blvd',
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Los Angeles',
#                                           'country': 'US',
#                                           'display_address': [   '6611 '
#                                                                  'Hollywood '
#                                                                  'Blvd',
#                                                                  'Los Angeles, '
#                                                                  'CA 90028'],
#                                           'state': 'CA',
#                                           'zip_code': '90028'},
#                           'name': 'Ice Cream Roll',
#                           'phone': '+13235788811',
#                           'price': '$',
#                           'rating': 4.5,
#                           'review_count': 8,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/ice-cream-roll-los-angeles-6?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'},
#                       {   'alias': 'pellegrinos-authentic-italian-food-upland',
#                           'categories': [   {   'alias': 'foodtrucks',
#                                                 'title': 'Food Trucks'},
#                                             {   'alias': 'catering',
#                                                 'title': 'Caterers'},
#                                             {   'alias': 'italian',
#                                                 'title': 'Italian'}],
#                           'coordinates': {   'latitude': 34.1040382385254,
#                                              'longitude': -117.670036315918},
#                           'display_phone': '(626) 233-7733',
#                           'distance': 45364.14290307576,
#                           'id': 'esEFM18aHAgmgLQ1E4WxuQ',
#                           'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uOn_WoOqLhH46UpudI-dlQ/o.jpg',
#                           'is_closed': False,
#                           'location': {   'address1': None,
#                                           'address2': None,
#                                           'address3': '',
#                                           'city': 'Upland',
#                                           'country': 'US',
#                                           'display_address': [   'Upland, CA '
#                                                                  '91786'],
#                                           'state': 'CA',
#                                           'zip_code': '91786'},
#                           'name': "Pellegrino's Authentic Italian Food",
#                           'phone': '+16262337733',
#                           'price': '$$',
#                           'rating': 5.0,
#                           'review_count': 38,
#                           'transactions': [],
#                           'url': 'https://www.yelp.com/biz/pellegrinos-authentic-italian-food-upland?adjust_creative=AJJp5ZbyG3U4JVXpf7gCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AJJp5ZbyG3U4JVXpf7gCgQ'}],
#     'region': {   'center': {   'latitude': 34.11379362655927,
#                                 'longitude': -118.15366744995117}},
#     'total': 243}

# %%
df_test = df_first.copy()

# %%
df_test['lat'] = df_test.apply(lambda x: x["coordinates"]["latitude"], axis=1)

# %%
df_test['distance'] = df_test.apply(lambda x: x["distance"] / 1000, axis=1)

# %%
df_test.head()
# Out:
#                        id                                          alias  \
# 0  JBmDS4EMDwfDSRq7kTDNqA                     son-of-a-bun-los-angeles-2
# 1  1SeCdGBjwEEO2MwJ7jPFeg  cousins-maine-lobster-los-angeles-los-angeles
# 2  o5AL9lZhfa6glcS0vrmdkg                  pepes-red-tacos-los-angeles-2
# 3  MMk7S8KK0PZazaQXlJkYbg              rockin-hot-chick-un-los-angeles-4
# 4  mviThK4Xf3urhQsQiEcfMQ                   a-gourmet-quickie-pasadena-2
#
#                                   name  \
# 0                         Son of a Bun
# 1  Cousins Maine Lobster - Los Angeles
# 2                     PEPE'S RED TACOS
# 3                  Rockin Hot Chick-un
# 4                    A Gourmet Quickie
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/pGJVdh...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/Zcieic...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/DTUrbO...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/LwJHOe...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/MYzkU7...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/son-of-a-bun-los-ange...           159
# 1  https://www.yelp.com/biz/cousins-maine-lobster...           978
# 2  https://www.yelp.com/biz/pepes-red-tacos-los-a...            46
# 3  https://www.yelp.com/biz/rockin-hot-chick-un-l...            54
# 4  https://www.yelp.com/biz/a-gourmet-quickie-pas...             1
#
#                                           categories  rating  \
# 0  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.5
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.5
# 2  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.5
# 3  [{'alias': 'tradamerican', 'title': 'American ...     5.0
# 4  [{'alias': 'foodstands', 'title': 'Food Stands'}]     5.0
#
#                                          coordinates        transactions  \
# 0    {'latitude': 34.04604, 'longitude': -118.24523}                  []
# 1    {'latitude': 34.05682, 'longitude': -118.24387}                  []
# 2  {'latitude': 34.0236288, 'longitude': -118.219...  [delivery, pickup]
# 3    {'latitude': 34.12086, 'longitude': -118.20525}  [delivery, pickup]
# 4  {'latitude': 34.14510767, 'longitude': -118.14...                  []
#
#   price                                           location         phone  \
# 0    $$  {'address1': '', 'address2': '', 'address3': '...  +12132899816
# 1    $$  {'address1': '', 'address2': None, 'address3':...  +18558554265
# 2     $  {'address1': '2720 E Olympic Blvd', 'address2'...  +13234827311
# 3   NaN  {'address1': '5050 York Blvd', 'address2': Non...  +13232437715
# 4   NaN  {'address1': '280 E Colorado Blvd', 'address2'...  +18182689976
#
#     display_phone   distance        lat
# 0  (213) 289-9816  15.638783  34.046040
# 1  (855) 855-4265  14.248051  34.056820
# 2  (323) 482-7311  16.328221  34.023629
# 3  (323) 243-7715   7.895504  34.120860
# 4  (818) 268-9976   1.926142  34.145108
