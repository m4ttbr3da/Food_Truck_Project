# %%
# Import dependencies

import requests
import pandas as pd
from pprint import pprint
from urllib.parse import quote
import matplotlib.pyplot as plt

# %%
# Build query

base_url = "http://data.streetfoodapp.com/1.1/"

city_url = base_url + "schedule/" + "vancouver"

city_url
# Out:
# 'http://data.streetfoodapp.com/1.1/schedule/vancouver'

# %%
response = requests.get(city_url).json()

response
# Out:
# {'metadata': {'ads': [{'banner': {'identifier': 'moms-grilled-cheese',
#      'image_url': 'https://cdn.streetfoodapp.com/images/moms-grilled-cheese/logo/90w.png',
#      'image_url_2x': 'https://cdn.streetfoodapp.com/images/moms-grilled-cheese/logo/90w@2x.png',
#      'title': "Mom's Grilled Cheese Truck",
#      'subtitle': 'Gourmet grilled cheese downtown at the Art Gallery.',
#      'show_vendor': 'moms-grilled-cheese'}}],
#   'new': ['crema-ice-cream',
#    'street-dogs-smash-burgers',
#    'rice-soup',
#    'santapan',
#    'steamworks',
#    'burgerholic',
#    'indish',
#    'the-praguery-2',
#    'namaste',
#    'kyu-grill'],
#   'regions': [{'identifier': 'vancouver',
#     'name': 'Vancouver',
#     'time_zone': 'America/Vancouver',
#     'example_location': [],
#     'regions': [{'identifier': 'armoury-district',
#       'name': 'Armoury District',
#       'time_zone': 'America/Vancouver'},
#      {'identifier': 'btc',
#       'name': 'Broadway Tech Centre',
# ...
